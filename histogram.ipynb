# %% [markdown]
# # Libraries required

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
food_hygiene = pd.read_csv('/vagrant/data/food-hygiene.csv', header=0)
food_hygiene
# Out:
#                                                Source Url  \
# 0       http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 1       http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 2       http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 3       http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 4       http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 5       http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 6       http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 7       http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 8       http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 9       http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 10      http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 11      http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 12      http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 13      http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# 14      http://ratings.food.gov.uk/OpenDataFiles%5CFHR...
# ...

# %%
# Check the number of rows and columns including the header rows
food_hygiene.shape
# Out:
# (348436, 13)

# %%
# Check our headers
food_hygiene.columns.values
# Out:
# array(['Source Url', 'Business Name', 'Business Type', 'Business Type Id',
#        'Address Line1', 'Post Code', 'Rating Value', 'Rating Date',
#        'Local Authority Code', 'Local Authority Name',
#        'Local Authority Website', 'Longitude', 'Latitude'], dtype=object)

# %%
# Let's check what types we have for each column
print type(food_hygiene['Source Url'][0])
print type(food_hygiene['Business Name'][0])
print type(food_hygiene['Business Type'][0])
print type(food_hygiene['Business Type Id'][0])
print type(food_hygiene['Address Line1'][0])
print type(food_hygiene['Post Code'][0])
print type(food_hygiene['Rating Value'][0])
print type(food_hygiene['Rating Date'][0])
print type(food_hygiene['Local Authority Code'][0])
print type(food_hygiene['Local Authority Name'][0])
print type(food_hygiene['Local Authority Website'][0])
print type(food_hygiene['Longitude'][0])
print type(food_hygiene['Latitude'][0])
# Out:
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'numpy.int64'>
# <type 'str'>
# <type 'str'>
# <type 'numpy.int64'>
# <type 'str'>
# <type 'numpy.int64'>
# <type 'str'>
# <type 'str'>
# <type 'numpy.float64'>
# <type 'numpy.float64'>

# %% [markdown]
# # Visualisation

# %%
# %matplotlib inline 
plt.hist(food_hygiene['Rating Value'], bins=[0,1,2,3,4,5])
# Out:
# (array([   1948.,   17982.,   13098.,   51729.,  263679.]),
#  array([0, 1, 2, 3, 4, 5]),
#  <a list of 5 Patch objects>)
